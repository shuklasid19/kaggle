# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir("C:/Users/sid/Downloads/Compressed/diamonds/")

# %%
df = pd.read_csv("diamonds.csv",index_col=0)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
#df["cut"].astype("category").cat.codes.head() #assigns arbitrary code

# %%
df["clarity"].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
cut_class_dict = {'Fair':1, 'Good':2 , 'Very Good':3, 'Premium':4, "Ideal":5}
clarity_dict = {"I3": 1, "I2": 2, "I1": 3, "SI2": 4, "SI1": 5, "VS2": 6, "VS1": 7, "VVS2": 8, "VVS1": 9, "IF": 10, "FL": 11}
color_dict = {"J": 1,"I": 2,"H": 3,"G": 4,"F": 5,"E": 6,"D": 7}

# %%
df["cut"] = df["cut"].map(cut_class_dict)
df["clarity"] = df["clarity"].map(clarity_dict)
df["color"] = df["color"].map(color_dict)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 1   0.23    5      6        4   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21    4      6        5   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23    2      6        7   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29    4      2        6   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31    2      1        4   63.3   58.0    335  4.34  4.35  2.75

# %%
import sklearn
from sklearn import svm, preprocessing

df = sklearn.utils.shuffle(df)
x = df.drop("price", axis=1).values #columns
x = preprocessing.scale(x)
y = df["price"].values

test_size = 200

x_train = x[:-test_size] 
y_train = y[:-test_size]

x_test = x[-test_size:]
y_test = y[-test_size:]

clf = svm.SVR(kernel="linear")
clf.fit(x_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
clf.score(x_test, y_test)
# Out:
# 0.9046920748486367

# %%
for x,y in zip(x_test, y_test):
    print(f"model: {clf.predict([x])[0]}, actual: {y}")
# Out:
# model: -220.48160190804492, actual: 453
# model: 3935.942614712055, actual: 2392
# model: 4489.271005424261, actual: 4601
# model: 488.0511560877417, actual: 710
# model: 6099.373427282557, actual: 7917
# model: 590.3355481914796, actual: 673
# model: -0.02365677699981461, actual: 672
# model: 2047.7047765559817, actual: 1607
# model: 6267.630006488204, actual: 7426
# model: 9153.75896003432, actual: 11345
# model: 2910.9132976454175, actual: 2440
# model: 4209.105020784456, actual: 3848
# model: 6642.738408049543, actual: 6758
# model: 13596.001841114447, actual: 14662
# model: 549.6557221071203, actual: 668
# model: -18.106515941864927, actual: 526
# model: 12363.603124918176, actual: 14238
# model: 2179.567154494838, actual: 1712
# model: 2494.708084216095, actual: 2242
# model: -242.07089557023392, actual: 432
# model: 134.40668556173114, actual: 802
# model: 5340.258026213876, actual: 7175
# model: 158.85354698421088, actual: 561
# model: 5206.945084126276, actual: 5469
# model: 1551.1493309242396, actual: 1167
# model: 1235.448796799265, actual: 1007
# model: 6039.705417567335, actual: 6163
# model: 757.8761507277632, actual: 969
# model: 2284.066844587313, actual: 1814
# model: 992.5025638495395, actual: 774
# model: 4487.97174608422, actual: 4132
# model: 417.09327310418576, actual: 541
# model: 1494.6713858323637, actual: 953
# model: 3537.3061235370333, actual: 2906
# model: 933.5582999903909, actual: 1197
# model: 7446.792457145217, actual: 6366
# model: 2476.043603434852, actual: 2242
# model: 2757.9855355457275, actual: 2410
# model: 90.74231304032355, actual: 776
# model: 1528.5820509778537, actual: 1097
# model: 365.75938799863934, actual: 765
# model: 5837.352436753899, actual: 4758
# model: 8661.56779016451, actual: 7740
# model: 6339.871272451119, actual: 6586
# model: 671.8416641230983, actual: 787
# model: 3071.0697821337144, actual: 2657
# model: -365.5343411210738, actual: 574
# model: 2996.267571030828, actual: 3376
# model: 4161.078683701869, actual: 3991
# model: 4909.777431618441, actual: 4395
# model: 1716.8486693646169, actual: 1806
# model: 2117.773115846213, actual: 1993
# model: 2346.8265526324117, actual: 2232
# model: 4449.57276053575, actual: 3812
# model: 9188.411948434357, actual: 12991
# model: 5092.837344632431, actual: 4139
# model: 2025.6013443347008, actual: 1857
# model: 3914.6351918013193, actual: 3697
# model: 115.95917034293825, actual: 709
# model: 3284.543418426125, actual: 2877
# model: 3366.8141744848735, actual: 3799
# model: 4973.089110972347, actual: 5461
# model: 2962.1929474674716, actual: 2500
# model: 10102.286050441397, actual: 9314
# model: 449.80464216366545, actual: 566
# model: 1830.8928531291924, actual: 1815
# model: 11672.984285290997, actual: 17600
# model: 807.090603825457, actual: 844
# model: 5253.339685304966, actual: 5181
# model: 5994.982814536962, actual: 3375
# model: 1523.9361230295276, actual: 1450
# model: 5902.999191248202, actual: 9724
# model: 804.1253254313706, actual: 827
# model: 2856.6970821893256, actual: 2593
# model: 4782.616690387145, actual: 5860
# model: 5781.999489675557, actual: 6546
# model: 481.03581402955206, actual: 900
# model: 2315.044573093139, actual: 2107
# model: 1622.9893425734922, actual: 1250
# model: 2176.925349674187, actual: 1750
# model: 649.8761958812547, actual: 827
# model: -37.79437413011419, actual: 544
# model: 11437.750468080481, actual: 12257
# model: 4425.332955730563, actual: 3640
# model: 932.5225256355734, actual: 975
# model: 225.02492065721663, actual: 844
# model: 12150.7470792861, actual: 15690
# model: 2545.7561426819716, actual: 2142
# model: 4819.341133103988, actual: 5861
# model: 2594.790431159132, actual: 2230
# model: 7198.797798503434, actual: 9032
# model: 504.68220605649185, actual: 956
# model: 4534.820735107491, actual: 4179
# model: 1332.8203303339428, actual: 1373
# model: 4788.320753066715, actual: 5115
# model: 837.2611816300191, actual: 1063
# model: 154.7934227114756, actual: 516
# model: 12096.99795505439, actual: 12612
# model: 8692.213112993522, actual: 11333
# model: 6421.114582394925, actual: 5924
# model: 6615.879747269473, actual: 5444
# model: 1189.6413031649613, actual: 1020
# model: 461.0096280733169, actual: 579
# model: 1521.6005805530813, actual: 1240
# model: 5186.337404340774, actual: 5521
# model: 4255.696762025068, actual: 3967
# model: 9464.372691002141, actual: 9158
# model: 3134.0340571220777, actual: 2833
# model: 4559.341008132591, actual: 4350
# model: 13245.672086833307, actual: 17127
# model: 11544.88471268216, actual: 12084
# model: 4873.075263317426, actual: 2774
# model: 1621.1652660627165, actual: 1610
# model: 3044.9841014936683, actual: 2671

# %%
clf = svm.SVR(kernel="rbv")
clf.fit(x_train, y_train)

# %%
clf.score(x_test, y_test)

# %%
for x,y in zip(x_test, y_test):
    print(f"model: {clf.predict([x])[0]}, actual: {y}")
